# %%
from battlehack20 import Game
from battlehack20.engine.container.instrument import Instrument
from RestrictedPython import compile_restricted
import dis
import math
from types import CodeType
import faulthandler
from types import SimpleNamespace

# %%
faulthandler.enable()

# %%
examplefuncs = """
import random


# This is an example bot written by the developers!
# Use this to help write your own code, or run it against your bot to see how well you can do!

DEBUG = 1
def dlog(str):
    if DEBUG > 0:
        log(str)


def check_space_wrapper(r, c, board_size):
    # check space, except doesn't hit you with game errors
    if r < 0 or c < 0 or c >= board_size or r >= board_size:
        return False
    try:
        return check_space(r, c)
    except:
        return None

def turn():
    dlog('Starting Turn!')
    board_size = get_board_size()

    team = get_team()
    opp_team = Team.WHITE if team == Team.BLACK else team.BLACK
    dlog('Team: ' + str(team))

    robottype = get_type()
    dlog('Type: ' + str(robottype))

    if robottype == RobotType.PAWN:
        row, col = get_location()
        dlog('My location is: ' + str(row) + ' ' + str(col))

        if team == Team.WHITE:
            forward = 1
        else:
            forward = -1

        # try catpuring pieces
        if check_space_wrapper(row + forward, col + 1, board_size) == opp_team: # up and right
            capture(row + forward, col + 1)
            dlog('Captured at: (' + str(row + forward) + ', ' + str(col + 1) + ')')
            # import pdb
            # pdb.set_trace()

        elif check_space_wrapper(row + forward, col - 1, board_size) == opp_team: # up and left
            capture(row + forward, col - 1)
            dlog('Captured at: (' + str(row + forward) + ', ' + str(col - 1) + ')')

        # otherwise try to move forward
        elif row + forward != -1 and row + forward != board_size and not check_space_wrapper(row + forward, col, board_size):
            #               ^  not off the board    ^            and    ^ directly forward is empty
            move_forward()
            dlog('Moved forward!')

        # confusion = "you need a line here to avoid segfault. we aren't sure why but are working on it"
        # ^ I think this is related to the potential ambiguity of what the following else is referring to?

    else:
        if team == Team.WHITE:
            index = 0
        else:
            index = board_size - 1

        for _ in range(board_size):
            i = random.randint(0, board_size - 1)
            if not check_space(index, i):
                spawn(index, i)
                dlog('Spawned unit at: (' + str(index) + ', ' + str(i) + ')')
                break

    bytecode = get_bytecode()
    dlog('Done! Bytecode left: ' + str(bytecode))

"""

# %%
examplefuncsturn = """
dlog('Starting Turn!')
board_size = get_board_size()

team = get_team()
opp_team = Team.WHITE if team == Team.BLACK else team.BLACK
dlog('Team: ' + str(team))

robottype = get_type()
dlog('Type: ' + str(robottype))

if robottype == RobotType.PAWN:
    row, col = get_location()
    dlog('My location is: ' + str(row) + ' ' + str(col))

    if team == Team.WHITE:
        forward = 1
    else:
        forward = -1

    # try catpuring pieces
    if check_space_wrapper(row + forward, col + 1, board_size) == opp_team: # up and right
        capture(row + forward, col + 1)
        dlog('Captured at: (' + str(row + forward) + ', ' + str(col + 1) + ')')

    elif check_space_wrapper(row + forward, col - 1, board_size) == opp_team: # up and left
        capture(row + forward, col - 1)
        dlog('Captured at: (' + str(row + forward) + ', ' + str(col - 1) + ')')

    # otherwise try to move forward
    elif row + forward != -1 and row + forward != board_size and not check_space_wrapper(row + forward, col, board_size):
        #               ^  not off the board    ^            and    ^ directly forward is empty
        move_forward()
        dlog('Moved forward!')

    # confusion = "you need a line here to avoid segfault. we aren't sure why but are working on it"
    # ^ I think this is related to the potential ambiguity of what the following else is referring to?

else:
    if team == Team.WHITE:
        index = 0
    else:
        index = board_size - 1

    for _ in range(board_size):
        i = random.randint(0, board_size - 1)
        if not check_space(index, i):
            spawn(index, i)
            dlog('Spawned unit at: (' + str(index) + ', ' + str(i) + ')')
            break

bytecode = get_bytecode()
dlog('Done! Bytecode left: ' + str(bytecode))
"""

# %%
class Instruction(SimpleNamespace):
    def __init__(self, instruction, in_dict=None):
        if in_dict is not None:
            super().__init__(**in_dict)
        else:
            super().__init__(**{a:b for a,b in zip(dis.Instruction._fields+('jump_to', 'was_there', 'extra_extended_args'), instruction + (None, True, 0))})

    def is_jumper(self):
        return self.is_abs_jumper() or self.is_rel_jumper()

    def is_rel_jumper(self):
        return self.opcode in dis.hasjrel

    def is_abs_jumper(self):
        return self.opcode in dis.hasjabs

    @classmethod
    def ExtendedArgs(self, value):
        return Instruction(None, in_dict={
            'opcode':144, 'opname':'EXTENDED_ARGS', 'arg':value,
            'argval':value, 'argrepr':value, 'offset':None,
            'starts_line':None, 'is_jump_target':False, 'was_there': False,
            'extra_extended_args': 0,
        })

    def calculate_offset(self, instructions):
        # Return the offset (rel or abs) to self.jump_to in instructions
        target_loc = 2 * instructions.index(self.jump_to) - 2 * self.jump_to.extra_extended_args

        if self.is_abs_jumper():
            return target_loc

        self_loc = 2 * instructions.index(self)

        return target_loc - self_loc - 2

# %%
def instrument(bytecode):
    """
    The primary method of instrumenting code, which involves injecting a bytecode counter between every instruction to be executed

    :param bytecode: a code object, the bytecode submitted by the player
    :return: a new code object that has been injected with our bytecode counter
    """

    # Ensure all code constants (e.g. list comprehensions) are also instrumented.
    new_consts = []
    for i, constant in enumerate(bytecode.co_consts):
        if type(constant) == CodeType:
            new_consts.append(instrument(constant))
        else:
            new_consts.append(constant)
    new_consts = tuple(new_consts)

    instructions = list(dis.get_instructions(bytecode))

    function_name_index = len(bytecode.co_names)  # we will be inserting our __instrument__ call at the end of co_names

    # the injection, which consists of a function call to an __instrument__ method which increments bytecode
    # these three instructions will be inserted between every line of instrumented code
    injection = [
        dis.Instruction(opcode=116, opname='LOAD_GLOBAL', arg=function_name_index%256, argval='__instrument__', argrepr='__instrument__', offset=None, starts_line=None, is_jump_target=False),
        dis.Instruction(opcode=131, opname='CALL_FUNCTION', arg=0, argval=0, argrepr=0, offset=None, starts_line=None, is_jump_target=False),
        dis.Instruction(opcode=1, opname='POP_TOP', arg=None, argval=None, argrepr=None, offset=None, starts_line=None, is_jump_target=False)
    ]
    #extends the opargs so that it can store the index of __instrument__
    while function_name_index > 255: #(255 = 2^8 -1 = 1 oparg)
        function_name_index >>= 8
        injection = [
            dis.Instruction(
                opcode=144,
                opname='EXTENDED_ARGS',
                arg=function_name_index%256,
                argval=function_name_index%256,
                argrepr=function_name_index%256,
                offset=None,
                starts_line=None,
                is_jump_target=False
            )
        ] + injection

    # For maintenance we add an empty jump_to field to each instruction
    for i, instruction in enumerate(instructions):
        instructions[i] = Instruction(instruction)

    # Next, we cache a reference to the jumpers to each jump target in the targets
    for i, instruction in enumerate(instructions):
        # We're only looking for jumpers
        if not instruction.is_jumper():
            continue

        target = [t for t in instructions if instruction.argval == t.offset][0]
        instruction.jump_to = target

        # If any targets jump to themselves, that's not kosher.
        if instruction == target:
            raise SyntaxError('No self-referential loops.')

    unsafe = {110, 113, 114, 115, 116, 120, 124, 125, 131, 93, 110, 120, 121, 122, 143, 154, 111, 112, 113, 114, 115, 119}  # bytecode ops that break the instrument

    # We then inject the injection before every call, except for those following an EXTENDED_ARGS.
    cur_index = -1
    for (cur, last) in zip(instructions[:], [None]+instructions[:-1]):
        cur_index += 1
        if last is not None and last.opcode == 144: #EXTEND_ARG
            continue

        if last is not None and last.opcode in unsafe:
            continue

        for j, inject in enumerate(injection):
            injected_instruction = Instruction(inject)
            injected_instruction.was_there = False # keeping track of the instructions added by us
            instructions.insert(cur_index + j, injected_instruction)
        cur_index += len(injection)


    # Iterate through instructions. If it's a jumper, calculate the new correct offset. For each new offset, if it
    # is too large to fit in the current number of EXTENDED_ARGS, inject a new EXTENDED_ARG before it. If you never
    # insert a new EXTENDED_ARGS, break out of the loop.
    fixed = False
    while not fixed:
        fixed = True
        
        print('not fixed!')

        i = 0
        for instruction in instructions[:]:
            instruction.offset = 2 * i

            if not instruction.is_jumper():
                i += 1
                continue

            correct_offset = instruction.calculate_offset(instructions)
            instruction.arg = correct_offset % 256
            correct_offset >>= 8
            print('fwt')
            extended_args = 0
            while correct_offset > 0:
                # Check if there is already an EXTENDED_ARGS behind
                if i > extended_args and instructions[i - extended_args - 1].opcode == 144:
                    instructions[i - extended_args - 1].arg = correct_offset % 256
                    print('hheekkkoo')

                # Otherwise, insert a new one
                else:
                    instructions.insert(i, Instruction.ExtendedArgs(correct_offset % 256))
                    instruction.extra_extended_args += 1
                    print('helo')
                    i += 1
                    fixed = False

                correct_offset >>= 8
                extended_args += 1
            i += 1
    #Maintaining correct line info ( traceback bug fix)
    #co_lnotab stores line information in Byte form
    # It stores alterantively, the number of instructions to the next increase in line number and
    # the increase in line number then
    #We need to ensure that these are bytes (You might want to break an increase into two see the article or code below)
    #The code did not update these bytes, we need to update the number of instructions before the beginning of each line
    #It should be similar to the way the jump to statement were fixed, I tried to mimick them but failed, I feel like I do not inderstand instruction.py
    # I am overestimating the number of instructions before the start of the line in this fix
    # you might find the end of this article helpful: https://towardsdatascience.com/understanding-python-bytecode-e7edaae8734d
    old_lnotab = {} #stores the old right info in a more usefull way (maps instruction num to line num)
    i = 0
    line_num = 0 #maintains line number by adding differences
    instruction_num = 0 #maintains the instruction num by addind differences
    while 2*i < len(bytecode.co_lnotab):
        instruction_num += bytecode.co_lnotab[2 * i]
        line_num += bytecode.co_lnotab[2 * i + 1]
        old_lnotab[instruction_num] = line_num
        i += 1
    #Construct a map from old instruction numbers, to new ones.
    num_injected = 0
    instruction_index = 0
    old_to_new_instruction_num = {}
    for instruction in instructions:
        if instruction.was_there:
            old_to_new_instruction_num[2 * (instruction_index - num_injected)] = 2 * instruction_index
        instruction_index += 1
        if not instruction.was_there:
            num_injected += 1
    new_lnotab = {}
    for key in old_lnotab:
        new_lnotab[old_to_new_instruction_num[key]] = old_lnotab[key]

    #Creating a differences list of integers, while ensuring integers in it are bytes
    pairs = sorted(new_lnotab.items())
    new_lnotab = []
    previous_pair = (0, 0)
    for pair in pairs:
        num_instructions = pair[0] - previous_pair[0]
        num_lines = pair[1] - previous_pair[1]
        while num_instructions > 127:
            new_lnotab.append(127)
            new_lnotab.append(0)
            num_instructions -= 127
        new_lnotab.append(num_instructions)
        while num_lines > 127:
            new_lnotab.append(127)
            new_lnotab.append(0)
            num_lines -= 127
        new_lnotab.append(num_lines)
        previous_pair = pair
    #tranfer to bytes and we are good :)
    new_lnotab = bytes(new_lnotab)

    # Finally, we repackage up our instructions into a byte string and use it to build a new code object
    byte_array = [[inst.opcode, 0 if inst.arg is None else inst.arg % 256] for inst in instructions]
    new_code = bytes(sum(byte_array, []))

    print('wtf')
    
    # Make sure our code can locate the __instrument__ call
    new_names = tuple(bytecode.co_names) + ('__instrument__', )

    return Instrument.build_code(bytecode, new_code, new_names, new_consts, new_lnotab)

# %%
exfuncs = compile_restricted(examplefuncs, 'bot.py', 'exec')

# %%
exfuncs = instrument(exfuncs)
# Out:
# not fixed!
# fwt
# wtf
# not fixed!
# fwt
# fwt
# fwt
# fwt
# fwt
# wtf
# not fixed!
# fwt
# fwt
# fwt
# hheekkkoo
# fwt
# helo
# fwt
# fwt
# hheekkkoo
# fwt
# helo
# fwt
# hheekkkoo
# fwt
# fwt
# hheekkkoo
# fwt
# hheekkkoo
# fwt
# hheekkkoo
# fwt
# helo
# fwt
# hheekkkoo
# fwt
# fwt
# fwt
# fwt
# hheekkkoo
# fwt
# hheekkkoo
# not fixed!
# fwt
# fwt
# fwt
# hheekkkoo
# fwt
# hheekkkoo
# fwt
# fwt
# hheekkkoo
# fwt
# hheekkkoo
# fwt
# hheekkkoo
# fwt
# fwt
# hheekkkoo
# fwt
# hheekkkoo
# fwt
# hheekkkoo
# fwt
# hheekkkoo
# fwt
# hheekkkoo
# fwt
# fwt
# fwt
# fwt
# hheekkkoo
# fwt
# hheekkkoo
# wtf
# not fixed!
# wtf

# %%
code = {'bot': exfuncs}

# %%
game = Game([code,code],debug=True)
# Out:
# [Game info] Seed: 1337

# %%
game.turn()
# Out:
# [Game info] Turn 12
# [Game info] Queue: {6: <ROBOT 6 WHITE>, 7: <ROBOT 7 BLACK>, 8: <ROBOT 8 BLACK>, 9: <ROBOT 9 WHITE>, 10: <ROBOT 10 WHITE>, 11: <ROBOT 11 BLACK>, 12: <ROBOT 12 BLACK>, 13: <ROBOT 13 WHITE>, 14: <ROBOT 14 WHITE>, 15: <ROBOT 15 BLACK>, 16: <ROBOT 16 BLACK>, 17: <ROBOT 17 WHITE>, 18: <ROBOT 18 WHITE>, 19: <ROBOT 19 BLACK>, 20: <ROBOT 20 BLACK>, 21: <ROBOT 21 WHITE>, 22: <ROBOT 22 WHITE>, 23: <ROBOT 23 BLACK>}
# [Game info] Lords: [<ROBOT BLACK HQ BLACK>, <ROBOT WHITE HQ WHITE>]
# [Robot 6 WHITE log] Starting Turn!
# [Robot 6 WHITE log] Team: Team.WHITE
# [Robot 6 WHITE log] Type: RobotType.PAWN
# [Robot 6 WHITE log] My location is: 8 12
# [Robot 6 WHITE log] Done! Bytecode left: 19917
# [Robot 7 BLACK log] Starting Turn!
# [Robot 7 BLACK log] Team: Team.BLACK
# [Robot 7 BLACK log] Type: RobotType.PAWN
# [Robot 7 BLACK log] My location is: 7 9
# [Robot 7 BLACK log] Moved forward!
# [Robot 7 BLACK log] Done! Bytecode left: 19909
# [Robot 8 BLACK log] Starting Turn!
# [Robot 8 BLACK log] Team: Team.BLACK
# [Robot 8 BLACK log] Type: RobotType.PAWN
# [Robot 8 BLACK log] My location is: 9 12
# [Robot 8 BLACK log] Done! Bytecode left: 19917
# [Robot 9 WHITE log] Starting Turn!
# [Robot 9 WHITE log] Team: Team.WHITE
# [Robot 9 WHITE log] Type: RobotType.PAWN
# [Robot 9 WHITE log] My location is: 7 5
# [Robot 9 WHITE log] Moved forward!
# [Robot 9 WHITE log] Done! Bytecode left: 19909
# [Robot 10 WHITE log] Starting Turn!
# [Robot 10 WHITE log] Team: Team.WHITE
# [Robot 10 WHITE log] Type: RobotType.PAWN
# [Robot 10 WHITE log] My location is: 6 11
# [Robot 10 WHITE log] Moved forward!
# [Robot 10 WHITE log] Done! Bytecode left: 19909
# [Robot 11 BLACK log] Starting Turn!
# [Robot 11 BLACK log] Team: Team.BLACK
# [Robot 11 BLACK log] Type: RobotType.PAWN
# [Robot 11 BLACK log] My location is: 9 3
# [Robot 11 BLACK log] Moved forward!
# [Robot 11 BLACK log] Done! Bytecode left: 19909
# [Robot 12 BLACK log] Starting Turn!
# [Robot 12 BLACK log] Team: Team.BLACK
# [Robot 12 BLACK log] Type: RobotType.PAWN
# [Robot 12 BLACK log] My location is: 10 13
# [Robot 12 BLACK log] Moved forward!
# [Robot 12 BLACK log] Done! Bytecode left: 19909
# [Robot 13 WHITE log] Starting Turn!
# [Robot 13 WHITE log] Team: Team.WHITE
# [Robot 13 WHITE log] Type: RobotType.PAWN
# [Robot 13 WHITE log] My location is: 5 12
# [Robot 13 WHITE log] Moved forward!
# [Robot 13 WHITE log] Done! Bytecode left: 19909
# [Robot 14 WHITE log] Starting Turn!
# [Robot 14 WHITE log] Team: Team.WHITE
# [Robot 14 WHITE log] Type: RobotType.PAWN
# [Robot 14 WHITE log] My location is: 4 2
# [Robot 14 WHITE log] Moved forward!
# [Robot 14 WHITE log] Done! Bytecode left: 19909
# [Robot 15 BLACK log] Starting Turn!
# [Robot 15 BLACK log] Team: Team.BLACK
# [Robot 15 BLACK log] Type: RobotType.PAWN
# [Robot 15 BLACK log] My location is: 11 11
# [Robot 15 BLACK log] Moved forward!
# [Robot 15 BLACK log] Done! Bytecode left: 19909
# [Robot 16 BLACK log] Starting Turn!
# [Robot 16 BLACK log] Team: Team.BLACK
# [Robot 16 BLACK log] Type: RobotType.PAWN
# [Robot 16 BLACK log] My location is: 12 12
# [Robot 16 BLACK log] Moved forward!
# [Robot 16 BLACK log] Done! Bytecode left: 19909
# [Robot 17 WHITE log] Starting Turn!
# [Robot 17 WHITE log] Team: Team.WHITE
# [Robot 17 WHITE log] Type: RobotType.PAWN
# [Robot 17 WHITE log] My location is: 3 12
# [Robot 17 WHITE log] Moved forward!
# [Robot 17 WHITE log] Done! Bytecode left: 19909
# [Robot 18 WHITE log] Starting Turn!
# [Robot 18 WHITE log] Team: Team.WHITE
# [Robot 18 WHITE log] Type: RobotType.PAWN
# [Robot 18 WHITE log] My location is: 2 9
# [Robot 18 WHITE log] Moved forward!
# [Robot 18 WHITE log] Done! Bytecode left: 19909
# [Robot 19 BLACK log] Starting Turn!
# [Robot 19 BLACK log] Team: Team.BLACK
# [Robot 19 BLACK log] Type: RobotType.PAWN
# [Robot 19 BLACK log] My location is: 13 0
# [Robot 19 BLACK log] Moved forward!
# [Robot 19 BLACK log] Done! Bytecode left: 19910
# [Robot 20 BLACK log] Starting Turn!
# [Robot 20 BLACK log] Team: Team.BLACK
# [Robot 20 BLACK log] Type: RobotType.PAWN
# [Robot 20 BLACK log] My location is: 14 11
# [Robot 20 BLACK log] Moved forward!
# [Robot 20 BLACK log] Done! Bytecode left: 19909
# [Robot 21 WHITE log] Starting Turn!
# [Robot 21 WHITE log] Team: Team.WHITE
# [Robot 21 WHITE log] Type: RobotType.PAWN
# [Robot 21 WHITE log] My location is: 1 3
# [Robot 21 WHITE log] Moved forward!
# [Robot 21 WHITE log] Done! Bytecode left: 19909
# [Robot 22 WHITE log] Starting Turn!
# [Robot 22 WHITE log] Team: Team.WHITE
# [Robot 22 WHITE log] Type: RobotType.PAWN
# [Robot 22 WHITE log] My location is: 0 14
# [Robot 22 WHITE log] Moved forward!
# [Robot 22 WHITE log] Done! Bytecode left: 19889
# [Robot 23 BLACK log] Starting Turn!
# [Robot 23 BLACK log] Team: Team.BLACK
# [Robot 23 BLACK log] Type: RobotType.PAWN
# [Robot 23 BLACK log] My location is: 15 7
# [Robot 23 BLACK log] Moved forward!
# [Robot 23 BLACK log] Done! Bytecode left: 19889
# [Robot BLACK HQ log] Starting Turn!
# [Robot BLACK HQ log] Team: Team.BLACK
# [Robot BLACK HQ log] Type: RobotType.OVERLORD
# [Robot BLACK HQ log] Spawned unit at: (15, 5)
# [Robot BLACK HQ log] Done! Bytecode left: 19948
# [Robot WHITE HQ log] Starting Turn!
# [Robot WHITE HQ log] Team: Team.WHITE
# [Robot WHITE HQ log] Type: RobotType.OVERLORD
# [Robot WHITE HQ log] Spawned unit at: (0, 10)
# [Robot WHITE HQ log] Done! Bytecode left: 19949

# %%
dis.hasjrel
# Out:
# [93, 110, 120, 121, 122, 143, 154]

# %%
dis.hasjabs
# Out:
# [111, 112, 113, 114, 115, 119]

# %%
s = """
if x == 1:
    if y == 1:
        print(x)
    else:
        print(y)
    x = 1
else:
    print(2)
"""

# %%
s2 = """
if x == 1:
    if y == 1:
        print(x)
    elif x == 1:
        print(z)
    else:
        print(y)
else:
    print(2)
"""

# %%
dis.dis(s)
# Out:
#   2           0 LOAD_NAME                0 (x)
#               2 LOAD_CONST               0 (1)
#               4 COMPARE_OP               2 (==)
#               6 POP_JUMP_IF_FALSE       40
#
#   3           8 LOAD_NAME                1 (y)
#              10 LOAD_CONST               0 (1)
#              12 COMPARE_OP               2 (==)
#              14 POP_JUMP_IF_FALSE       26
#
#   4          16 LOAD_NAME                2 (print)
#              18 LOAD_NAME                0 (x)
#              20 CALL_FUNCTION            1
#              22 POP_TOP
#              24 JUMP_FORWARD             8 (to 34)
#
#   6     >>   26 LOAD_NAME                2 (print)
#              28 LOAD_NAME                1 (y)
#              30 CALL_FUNCTION            1
#              32 POP_TOP
#
#   7     >>   34 LOAD_CONST               0 (1)
#              36 STORE_NAME               0 (x)
#              38 JUMP_FORWARD             8 (to 48)
#
#   9     >>   40 LOAD_NAME                2 (print)
#              42 LOAD_CONST               1 (2)
#              44 CALL_FUNCTION            1
#              46 POP_TOP
#         >>   48 LOAD_CONST               2 (None)
#              50 RETURN_VALUE

# %%
dis.dis(s2)
# Out:
#   2           0 LOAD_NAME                0 (x)
#               2 LOAD_CONST               0 (1)
#               4 COMPARE_OP               2 (==)
#               6 POP_JUMP_IF_FALSE       54
#
#   3           8 LOAD_NAME                1 (y)
#              10 LOAD_CONST               0 (1)
#              12 COMPARE_OP               2 (==)
#              14 POP_JUMP_IF_FALSE       26
#
#   4          16 LOAD_NAME                2 (print)
#              18 LOAD_NAME                0 (x)
#              20 CALL_FUNCTION            1
#              22 POP_TOP
#              24 JUMP_ABSOLUTE           62
#
#   5     >>   26 LOAD_NAME                0 (x)
#              28 LOAD_CONST               0 (1)
#              30 COMPARE_OP               2 (==)
#              32 POP_JUMP_IF_FALSE       44
#
#   6          34 LOAD_NAME                2 (print)
#              36 LOAD_NAME                3 (z)
#              38 CALL_FUNCTION            1
#              40 POP_TOP
#              42 JUMP_ABSOLUTE           62
#
#   8     >>   44 LOAD_NAME                2 (print)
#              46 LOAD_NAME                1 (y)
#              48 CALL_FUNCTION            1
#              50 POP_TOP
#              52 JUMP_FORWARD             8 (to 62)
#
#  10     >>   54 LOAD_NAME                2 (print)
#              56 LOAD_CONST               1 (2)
#              58 CALL_FUNCTION            1
#              60 POP_TOP
#         >>   62 LOAD_CONST               2 (None)
#              64 RETURN_VALUE

# %%
dis.dis(exfuncs)
# Out:
#   2           0 LOAD_GLOBAL             30 (__instrument__)
#               2 CALL_FUNCTION            0
#               4 POP_TOP
#               6 LOAD_NAME                0 (dlog)
#               8 LOAD_GLOBAL             30 (__instrument__)
#              10 CALL_FUNCTION            0
#              12 POP_TOP
#              14 LOAD_CONST               0 ('Starting Turn!')
#              16 LOAD_GLOBAL             30 (__instrument__)
#              18 CALL_FUNCTION            0
#              20 POP_TOP
#              22 CALL_FUNCTION            1
#              24 POP_TOP
#              26 LOAD_GLOBAL             30 (__instrument__)
#              28 CALL_FUNCTION            0
#              30 POP_TOP
#
#   3          32 LOAD_NAME                1 (get_board_size)
#              34 LOAD_GLOBAL             30 (__instrument__)
#              36 CALL_FUNCTION            0
#              38 POP_TOP
#              40 CALL_FUNCTION            0
#              42 STORE_NAME               2 (board_size)
#              44 LOAD_GLOBAL             30 (__instrument__)
#              46 CALL_FUNCTION            0
#              48 POP_TOP
#
#   5          50 LOAD_NAME                3 (get_team)
#              52 LOAD_GLOBAL             30 (__instrument__)
#              54 CALL_FUNCTION            0
#              56 POP_TOP
#              58 CALL_FUNCTION            0
#              60 STORE_NAME               4 (team)
#              62 LOAD_GLOBAL             30 (__instrument__)
#              64 CALL_FUNCTION            0
#              66 POP_TOP
#
#   6          68 LOAD_NAME                4 (team)
#              70 LOAD_GLOBAL             30 (__instrument__)
#              72 CALL_FUNCTION            0
#              74 POP_TOP
#              76 LOAD_NAME                5 (_getattr_)
#              78 LOAD_GLOBAL             30 (__instrument__)
#              80 CALL_FUNCTION            0
#              82 POP_TOP
#              84 LOAD_NAME                6 (Team)
#              86 LOAD_GLOBAL             30 (__instrument__)
#              88 CALL_FUNCTION            0
#              90 POP_TOP
#              92 LOAD_CONST               1 ('BLACK')
#              94 LOAD_GLOBAL             30 (__instrument__)
#              96 CALL_FUNCTION            0
#              98 POP_TOP
#             100 CALL_FUNCTION            2
#             102 COMPARE_OP               2 (==)
#             104 LOAD_GLOBAL             30 (__instrument__)
#             106 CALL_FUNCTION            0
#             108 POP_TOP
#             110 POP_JUMP_IF_FALSE      140
#             112 LOAD_NAME                5 (_getattr_)
#             114 LOAD_GLOBAL             30 (__instrument__)
#             116 CALL_FUNCTION            0
#             118 POP_TOP
#             120 LOAD_NAME                6 (Team)
#             122 LOAD_GLOBAL             30 (__instrument__)
#             124 CALL_FUNCTION            0
#             126 POP_TOP
#             128 LOAD_CONST               2 ('WHITE')
#             130 LOAD_GLOBAL             30 (__instrument__)
#             132 CALL_FUNCTION            0
#             134 POP_TOP
#             136 CALL_FUNCTION            2
#             138 JUMP_FORWARD            26 (to 166)
#         >>  140 LOAD_NAME                5 (_getattr_)
#             142 LOAD_GLOBAL             30 (__instrument__)
#             144 CALL_FUNCTION            0
#             146 POP_TOP
#             148 LOAD_NAME                4 (team)
#             150 LOAD_GLOBAL             30 (__instrument__)
#             152 CALL_FUNCTION            0
#             154 POP_TOP
#             156 LOAD_CONST               1 ('BLACK')
#             158 LOAD_GLOBAL             30 (__instrument__)
#             160 CALL_FUNCTION            0
#             162 POP_TOP
#             164 CALL_FUNCTION            2
#         >>  166 STORE_NAME               7 (opp_team)
#             168 LOAD_GLOBAL             30 (__instrument__)
#             170 CALL_FUNCTION            0
#             172 POP_TOP
#
#   7         174 LOAD_NAME                0 (dlog)
#             176 LOAD_GLOBAL             30 (__instrument__)
#             178 CALL_FUNCTION            0
#             180 POP_TOP
#             182 LOAD_CONST               3 ('Team: ')
#             184 LOAD_GLOBAL             30 (__instrument__)
#             186 CALL_FUNCTION            0
#             188 POP_TOP
#             190 LOAD_NAME                8 (str)
#             192 LOAD_GLOBAL             30 (__instrument__)
#             194 CALL_FUNCTION            0
#             196 POP_TOP
#             198 LOAD_NAME                4 (team)
#             200 LOAD_GLOBAL             30 (__instrument__)
#             202 CALL_FUNCTION            0
#             204 POP_TOP
#             206 CALL_FUNCTION            1
#             208 BINARY_ADD
#             210 LOAD_GLOBAL             30 (__instrument__)
#             212 CALL_FUNCTION            0
#             214 POP_TOP
#             216 CALL_FUNCTION            1
#             218 POP_TOP
#             220 LOAD_GLOBAL             30 (__instrument__)
#             222 CALL_FUNCTION            0
#             224 POP_TOP
#
#   9         226 LOAD_NAME                9 (get_type)
#             228 LOAD_GLOBAL             30 (__instrument__)
#             230 CALL_FUNCTION            0
#             232 POP_TOP
#             234 CALL_FUNCTION            0
#             236 STORE_NAME              10 (robottype)
#             238 LOAD_GLOBAL             30 (__instrument__)
#             240 CALL_FUNCTION            0
#             242 POP_TOP
#
#  10         244 LOAD_NAME                0 (dlog)
#             246 LOAD_GLOBAL             30 (__instrument__)
#             248 CALL_FUNCTION            0
#             250 POP_TOP
#             252 LOAD_CONST               4 ('Type: ')
#             254 LOAD_GLOBAL             30 (__instrument__)
#             256 CALL_FUNCTION            0
#             258 POP_TOP
#             260 LOAD_NAME                8 (str)
#             262 LOAD_GLOBAL             30 (__instrument__)
#             264 CALL_FUNCTION            0
#             266 POP_TOP
#             268 LOAD_NAME               10 (robottype)
#             270 LOAD_GLOBAL             30 (__instrument__)
#             272 CALL_FUNCTION            0
#             274 POP_TOP
#             276 CALL_FUNCTION            1
#             278 BINARY_ADD
#             280 LOAD_GLOBAL             30 (__instrument__)
#             282 CALL_FUNCTION            0
#             284 POP_TOP
#             286 CALL_FUNCTION            1
#             288 POP_TOP
#             290 LOAD_GLOBAL             30 (__instrument__)
#             292 CALL_FUNCTION            0
#             294 POP_TOP
#
#  12         296 LOAD_NAME               10 (robottype)
#             298 LOAD_GLOBAL             30 (__instrument__)
#             300 CALL_FUNCTION            0
#             302 POP_TOP
#             304 LOAD_NAME                5 (_getattr_)
#             306 LOAD_GLOBAL             30 (__instrument__)
#             308 CALL_FUNCTION            0
#             310 POP_TOP
#             312 LOAD_NAME               11 (RobotType)
#             314 LOAD_GLOBAL             30 (__instrument__)
#             316 CALL_FUNCTION            0
#             318 POP_TOP
#             320 LOAD_CONST               5 ('PAWN')
#             322 LOAD_GLOBAL             30 (__instrument__)
#             324 CALL_FUNCTION            0
#             326 POP_TOP
#             328 CALL_FUNCTION            2
#             330 COMPARE_OP               2 (==)
#             332 LOAD_GLOBAL             30 (__instrument__)
#             334 CALL_FUNCTION            0
#             336 POP_TOP
#             338 EXTENDED_ARG             5
#             340 POP_JUMP_IF_FALSE     1384
#
#  13         342 LOAD_NAME               12 (_unpack_sequence_)
#             344 LOAD_GLOBAL             30 (__instrument__)
#             346 CALL_FUNCTION            0
#             348 POP_TOP
#             350 LOAD_NAME               13 (get_location)
#             352 LOAD_GLOBAL             30 (__instrument__)
#             354 CALL_FUNCTION            0
#             356 POP_TOP
#             358 CALL_FUNCTION            0
#             360 LOAD_CONST               6 (())
#             362 LOAD_GLOBAL             30 (__instrument__)
#             364 CALL_FUNCTION            0
#             366 POP_TOP
#             368 LOAD_CONST               7 (2)
#             370 LOAD_GLOBAL             30 (__instrument__)
#             372 CALL_FUNCTION            0
#             374 POP_TOP
#             376 LOAD_CONST               8 (('childs', 'min_len'))
#             378 LOAD_GLOBAL             30 (__instrument__)
#             380 CALL_FUNCTION            0
#             382 POP_TOP
#             384 BUILD_CONST_KEY_MAP      2
#             386 LOAD_GLOBAL             30 (__instrument__)
#             388 CALL_FUNCTION            0
#             390 POP_TOP
#             392 LOAD_NAME               14 (_getiter_)
#             394 LOAD_GLOBAL             30 (__instrument__)
#             396 CALL_FUNCTION            0
#             398 POP_TOP
#             400 CALL_FUNCTION            3
#             402 UNPACK_SEQUENCE          2
#             404 LOAD_GLOBAL             30 (__instrument__)
#             406 CALL_FUNCTION            0
#             408 POP_TOP
#             410 STORE_NAME              15 (row)
#             412 LOAD_GLOBAL             30 (__instrument__)
#             414 CALL_FUNCTION            0
#             416 POP_TOP
#             418 STORE_NAME              16 (col)
#             420 LOAD_GLOBAL             30 (__instrument__)
#             422 CALL_FUNCTION            0
#             424 POP_TOP
#
#  14         426 LOAD_NAME                0 (dlog)
#             428 LOAD_GLOBAL             30 (__instrument__)
#             430 CALL_FUNCTION            0
#             432 POP_TOP
#             434 LOAD_CONST               9 ('My location is: ')
#             436 LOAD_GLOBAL             30 (__instrument__)
#             438 CALL_FUNCTION            0
#             440 POP_TOP
#             442 LOAD_NAME                8 (str)
#             444 LOAD_GLOBAL             30 (__instrument__)
#             446 CALL_FUNCTION            0
#             448 POP_TOP
#             450 LOAD_NAME               15 (row)
#             452 LOAD_GLOBAL             30 (__instrument__)
#             454 CALL_FUNCTION            0
#             456 POP_TOP
#             458 CALL_FUNCTION            1
#             460 BINARY_ADD
#             462 LOAD_GLOBAL             30 (__instrument__)
#             464 CALL_FUNCTION            0
#             466 POP_TOP
#             468 LOAD_CONST              10 (' ')
#             470 LOAD_GLOBAL             30 (__instrument__)
#             472 CALL_FUNCTION            0
#             474 POP_TOP
#             476 BINARY_ADD
#             478 LOAD_GLOBAL             30 (__instrument__)
#             480 CALL_FUNCTION            0
#             482 POP_TOP
#             484 LOAD_NAME                8 (str)
#             486 LOAD_GLOBAL             30 (__instrument__)
#             488 CALL_FUNCTION            0
#             490 POP_TOP
#             492 LOAD_NAME               16 (col)
#             494 LOAD_GLOBAL             30 (__instrument__)
#             496 CALL_FUNCTION            0
#             498 POP_TOP
#             500 CALL_FUNCTION            1
#             502 BINARY_ADD
#             504 LOAD_GLOBAL             30 (__instrument__)
#             506 CALL_FUNCTION            0
#             508 POP_TOP
#             510 CALL_FUNCTION            1
#             512 POP_TOP
#             514 LOAD_GLOBAL             30 (__instrument__)
#             516 CALL_FUNCTION            0
#             518 POP_TOP
#
#  16         520 LOAD_NAME                4 (team)
#             522 LOAD_GLOBAL             30 (__instrument__)
#             524 CALL_FUNCTION            0
#             526 POP_TOP
#             528 LOAD_NAME                5 (_getattr_)
#             530 LOAD_GLOBAL             30 (__instrument__)
#             532 CALL_FUNCTION            0
#             534 POP_TOP
#             536 LOAD_NAME                6 (Team)
#             538 LOAD_GLOBAL             30 (__instrument__)
#             540 CALL_FUNCTION            0
#             542 POP_TOP
#             544 LOAD_CONST               2 ('WHITE')
#             546 LOAD_GLOBAL             30 (__instrument__)
#             548 CALL_FUNCTION            0
#             550 POP_TOP
#             552 CALL_FUNCTION            2
#             554 COMPARE_OP               2 (==)
#             556 LOAD_GLOBAL             30 (__instrument__)
#             558 CALL_FUNCTION            0
#             560 POP_TOP
#             562 EXTENDED_ARG             2
#             564 POP_JUMP_IF_FALSE      584
#
#  17         566 LOAD_CONST              11 (1)
#             568 LOAD_GLOBAL             30 (__instrument__)
#             570 CALL_FUNCTION            0
#             572 POP_TOP
#             574 STORE_NAME              17 (forward)
#             576 LOAD_GLOBAL             30 (__instrument__)
#             578 CALL_FUNCTION            0
#             580 POP_TOP
#             582 JUMP_FORWARD            16 (to 600)
#
#  19     >>  584 LOAD_CONST              12 (-1)
#             586 LOAD_GLOBAL             30 (__instrument__)
#             588 CALL_FUNCTION            0
#             590 POP_TOP
#             592 STORE_NAME              17 (forward)
#             594 LOAD_GLOBAL             30 (__instrument__)
#             596 CALL_FUNCTION            0
#             598 POP_TOP
#
#  22     >>  600 LOAD_NAME               18 (check_space_wrapper)
#             602 LOAD_GLOBAL             30 (__instrument__)
#             604 CALL_FUNCTION            0
#             606 POP_TOP
#             608 LOAD_NAME               15 (row)
#             610 LOAD_GLOBAL             30 (__instrument__)
#             612 CALL_FUNCTION            0
#             614 POP_TOP
#             616 LOAD_NAME               17 (forward)
#             618 LOAD_GLOBAL             30 (__instrument__)
#             620 CALL_FUNCTION            0
#             622 POP_TOP
#             624 BINARY_ADD
#             626 LOAD_GLOBAL             30 (__instrument__)
#             628 CALL_FUNCTION            0
#             630 POP_TOP
#             632 LOAD_NAME               16 (col)
#             634 LOAD_GLOBAL             30 (__instrument__)
#             636 CALL_FUNCTION            0
#             638 POP_TOP
#             640 LOAD_CONST              11 (1)
#             642 LOAD_GLOBAL             30 (__instrument__)
#             644 CALL_FUNCTION            0
#             646 POP_TOP
#             648 BINARY_ADD
#             650 LOAD_GLOBAL             30 (__instrument__)
#             652 CALL_FUNCTION            0
#             654 POP_TOP
#             656 LOAD_NAME                2 (board_size)
#             658 LOAD_GLOBAL             30 (__instrument__)
#             660 CALL_FUNCTION            0
#             662 POP_TOP
#             664 CALL_FUNCTION            3
#             666 LOAD_NAME                7 (opp_team)
#             668 LOAD_GLOBAL             30 (__instrument__)
#             670 CALL_FUNCTION            0
#             672 POP_TOP
#             674 COMPARE_OP               2 (==)
#             676 LOAD_GLOBAL             30 (__instrument__)
#             678 CALL_FUNCTION            0
#             680 POP_TOP
#             682 EXTENDED_ARG             3
#             684 POP_JUMP_IF_FALSE      898
#
#  23         686 LOAD_NAME               19 (capture)
#             688 LOAD_GLOBAL             30 (__instrument__)
#             690 CALL_FUNCTION            0
#             692 POP_TOP
#             694 LOAD_NAME               15 (row)
#             696 LOAD_GLOBAL             30 (__instrument__)
#             698 CALL_FUNCTION            0
#             700 POP_TOP
#             702 LOAD_NAME               17 (forward)
#             704 LOAD_GLOBAL             30 (__instrument__)
#             706 CALL_FUNCTION            0
#             708 POP_TOP
#             710 BINARY_ADD
#             712 LOAD_GLOBAL             30 (__instrument__)
#             714 CALL_FUNCTION            0
#             716 POP_TOP
#             718 LOAD_NAME               16 (col)
#             720 LOAD_GLOBAL             30 (__instrument__)
#             722 CALL_FUNCTION            0
#             724 POP_TOP
#             726 LOAD_CONST              11 (1)
#             728 LOAD_GLOBAL             30 (__instrument__)
#             730 CALL_FUNCTION            0
#             732 POP_TOP
#             734 BINARY_ADD
#             736 LOAD_GLOBAL             30 (__instrument__)
#             738 CALL_FUNCTION            0
#             740 POP_TOP
#             742 CALL_FUNCTION            2
#             744 POP_TOP
#             746 LOAD_GLOBAL             30 (__instrument__)
#             748 CALL_FUNCTION            0
#             750 POP_TOP
#
#  24         752 LOAD_NAME                0 (dlog)
#             754 LOAD_GLOBAL             30 (__instrument__)
#             756 CALL_FUNCTION            0
#             758 POP_TOP
#             760 LOAD_CONST              13 ('Captured at: (')
#             762 LOAD_GLOBAL             30 (__instrument__)
#             764 CALL_FUNCTION            0
#             766 POP_TOP
#             768 LOAD_NAME                8 (str)
#             770 LOAD_GLOBAL             30 (__instrument__)
#             772 CALL_FUNCTION            0
#             774 POP_TOP
#             776 LOAD_NAME               15 (row)
#             778 LOAD_GLOBAL             30 (__instrument__)
#             780 CALL_FUNCTION            0
#             782 POP_TOP
#             784 LOAD_NAME               17 (forward)
#             786 LOAD_GLOBAL             30 (__instrument__)
#             788 CALL_FUNCTION            0
#             790 POP_TOP
#             792 BINARY_ADD
#             794 LOAD_GLOBAL             30 (__instrument__)
#             796 CALL_FUNCTION            0
#             798 POP_TOP
#             800 CALL_FUNCTION            1
#             802 BINARY_ADD
#             804 LOAD_GLOBAL             30 (__instrument__)
#             806 CALL_FUNCTION            0
#             808 POP_TOP
#             810 LOAD_CONST              14 (', ')
#             812 LOAD_GLOBAL             30 (__instrument__)
#             814 CALL_FUNCTION            0
#             816 POP_TOP
#             818 BINARY_ADD
#             820 LOAD_GLOBAL             30 (__instrument__)
#             822 CALL_FUNCTION            0
#             824 POP_TOP
#             826 LOAD_NAME                8 (str)
#             828 LOAD_GLOBAL             30 (__instrument__)
#             830 CALL_FUNCTION            0
#             832 POP_TOP
#             834 LOAD_NAME               16 (col)
#             836 LOAD_GLOBAL             30 (__instrument__)
#             838 CALL_FUNCTION            0
#             840 POP_TOP
#             842 LOAD_CONST              11 (1)
#             844 LOAD_GLOBAL             30 (__instrument__)
#             846 CALL_FUNCTION            0
#             848 POP_TOP
#             850 BINARY_ADD
#             852 LOAD_GLOBAL             30 (__instrument__)
#             854 CALL_FUNCTION            0
#             856 POP_TOP
#             858 CALL_FUNCTION            1
#             860 BINARY_ADD
#             862 LOAD_GLOBAL             30 (__instrument__)
#             864 CALL_FUNCTION            0
#             866 POP_TOP
#             868 LOAD_CONST              15 (')')
#             870 LOAD_GLOBAL             30 (__instrument__)
#             872 CALL_FUNCTION            0
#             874 POP_TOP
#             876 BINARY_ADD
#             878 LOAD_GLOBAL             30 (__instrument__)
#             880 CALL_FUNCTION            0
#             882 POP_TOP
#             884 CALL_FUNCTION            1
#             886 POP_TOP
#             888 LOAD_GLOBAL             30 (__instrument__)
#             890 CALL_FUNCTION            0
#             892 POP_TOP
#             894 EXTENDED_ARG             1
#             896 JUMP_FORWARD           482 (to 1380)
#
#  26     >>  898 LOAD_NAME               18 (check_space_wrapper)
#             900 LOAD_GLOBAL             30 (__instrument__)
#             902 CALL_FUNCTION            0
#             904 POP_TOP
#             906 LOAD_NAME               15 (row)
#             908 LOAD_GLOBAL             30 (__instrument__)
#             910 CALL_FUNCTION            0
#             912 POP_TOP
#             914 LOAD_NAME               17 (forward)
#             916 LOAD_GLOBAL             30 (__instrument__)
#             918 CALL_FUNCTION            0
#             920 POP_TOP
#             922 BINARY_ADD
#             924 LOAD_GLOBAL             30 (__instrument__)
#             926 CALL_FUNCTION            0
#             928 POP_TOP
#             930 LOAD_NAME               16 (col)
#             932 LOAD_GLOBAL             30 (__instrument__)
#             934 CALL_FUNCTION            0
#             936 POP_TOP
#             938 LOAD_CONST              11 (1)
#             940 LOAD_GLOBAL             30 (__instrument__)
#             942 CALL_FUNCTION            0
#             944 POP_TOP
#             946 BINARY_SUBTRACT
#             948 LOAD_GLOBAL             30 (__instrument__)
#             950 CALL_FUNCTION            0
#             952 POP_TOP
#             954 LOAD_NAME                2 (board_size)
#             956 LOAD_GLOBAL             30 (__instrument__)
#             958 CALL_FUNCTION            0
#             960 POP_TOP
#             962 CALL_FUNCTION            3
#             964 LOAD_NAME                7 (opp_team)
#             966 LOAD_GLOBAL             30 (__instrument__)
#             968 CALL_FUNCTION            0
#             970 POP_TOP
#             972 COMPARE_OP               2 (==)
#             974 LOAD_GLOBAL             30 (__instrument__)
#             976 CALL_FUNCTION            0
#             978 POP_TOP
#             980 EXTENDED_ARG             4
#             982 POP_JUMP_IF_FALSE     1194
#
#  27         984 LOAD_NAME               19 (capture)
#             986 LOAD_GLOBAL             30 (__instrument__)
#             988 CALL_FUNCTION            0
#             990 POP_TOP
#             992 LOAD_NAME               15 (row)
#             994 LOAD_GLOBAL             30 (__instrument__)
#             996 CALL_FUNCTION            0
#             998 POP_TOP
#            1000 LOAD_NAME               17 (forward)
#            1002 LOAD_GLOBAL             30 (__instrument__)
#            1004 CALL_FUNCTION            0
#            1006 POP_TOP
#            1008 BINARY_ADD
#            1010 LOAD_GLOBAL             30 (__instrument__)
#            1012 CALL_FUNCTION            0
#            1014 POP_TOP
#            1016 LOAD_NAME               16 (col)
#            1018 LOAD_GLOBAL             30 (__instrument__)
#            1020 CALL_FUNCTION            0
#            1022 POP_TOP
#            1024 LOAD_CONST              11 (1)
#            1026 LOAD_GLOBAL             30 (__instrument__)
#            1028 CALL_FUNCTION            0
#            1030 POP_TOP
#            1032 BINARY_SUBTRACT
#            1034 LOAD_GLOBAL             30 (__instrument__)
#            1036 CALL_FUNCTION            0
#            1038 POP_TOP
#            1040 CALL_FUNCTION            2
#            1042 POP_TOP
#            1044 LOAD_GLOBAL             30 (__instrument__)
#            1046 CALL_FUNCTION            0
#            1048 POP_TOP
#
#  28        1050 LOAD_NAME                0 (dlog)
#            1052 LOAD_GLOBAL             30 (__instrument__)
#            1054 CALL_FUNCTION            0
#            1056 POP_TOP
#            1058 LOAD_CONST              13 ('Captured at: (')
#            1060 LOAD_GLOBAL             30 (__instrument__)
#            1062 CALL_FUNCTION            0
#            1064 POP_TOP
#            1066 LOAD_NAME                8 (str)
#            1068 LOAD_GLOBAL             30 (__instrument__)
#            1070 CALL_FUNCTION            0
#            1072 POP_TOP
#            1074 LOAD_NAME               15 (row)
#            1076 LOAD_GLOBAL             30 (__instrument__)
#            1078 CALL_FUNCTION            0
#            1080 POP_TOP
#            1082 LOAD_NAME               17 (forward)
#            1084 LOAD_GLOBAL             30 (__instrument__)
#            1086 CALL_FUNCTION            0
#            1088 POP_TOP
#            1090 BINARY_ADD
#            1092 LOAD_GLOBAL             30 (__instrument__)
#            1094 CALL_FUNCTION            0
#            1096 POP_TOP
#            1098 CALL_FUNCTION            1
#            1100 BINARY_ADD
#            1102 LOAD_GLOBAL             30 (__instrument__)
#            1104 CALL_FUNCTION            0
#            1106 POP_TOP
#            1108 LOAD_CONST              14 (', ')
#            1110 LOAD_GLOBAL             30 (__instrument__)
#            1112 CALL_FUNCTION            0
#            1114 POP_TOP
#            1116 BINARY_ADD
#            1118 LOAD_GLOBAL             30 (__instrument__)
#            1120 CALL_FUNCTION            0
#            1122 POP_TOP
#            1124 LOAD_NAME                8 (str)
#            1126 LOAD_GLOBAL             30 (__instrument__)
#            1128 CALL_FUNCTION            0
#            1130 POP_TOP
#            1132 LOAD_NAME               16 (col)
#            1134 LOAD_GLOBAL             30 (__instrument__)
#            1136 CALL_FUNCTION            0
#            1138 POP_TOP
#            1140 LOAD_CONST              11 (1)
#            1142 LOAD_GLOBAL             30 (__instrument__)
#            1144 CALL_FUNCTION            0
#            1146 POP_TOP
#            1148 BINARY_SUBTRACT
#            1150 LOAD_GLOBAL             30 (__instrument__)
#            1152 CALL_FUNCTION            0
#            1154 POP_TOP
#            1156 CALL_FUNCTION            1
#            1158 BINARY_ADD
#            1160 LOAD_GLOBAL             30 (__instrument__)
#            1162 CALL_FUNCTION            0
#            1164 POP_TOP
#            1166 LOAD_CONST              15 (')')
#            1168 LOAD_GLOBAL             30 (__instrument__)
#            1170 CALL_FUNCTION            0
#            1172 POP_TOP
#            1174 BINARY_ADD
#            1176 LOAD_GLOBAL             30 (__instrument__)
#            1178 CALL_FUNCTION            0
#            1180 POP_TOP
#            1182 CALL_FUNCTION            1
#            1184 POP_TOP
#            1186 LOAD_GLOBAL             30 (__instrument__)
#            1188 CALL_FUNCTION            0
#            1190 POP_TOP
#            1192 JUMP_FORWARD           186 (to 1380)
#
#  31     >> 1194 LOAD_NAME               15 (row)
#            1196 LOAD_GLOBAL             30 (__instrument__)
#            1198 CALL_FUNCTION            0
#            1200 POP_TOP
#            1202 LOAD_NAME               17 (forward)
#            1204 LOAD_GLOBAL             30 (__instrument__)
#            1206 CALL_FUNCTION            0
#            1208 POP_TOP
#            1210 BINARY_ADD
#            1212 LOAD_GLOBAL             30 (__instrument__)
#            1214 CALL_FUNCTION            0
#            1216 POP_TOP
#            1218 LOAD_CONST              12 (-1)
#            1220 LOAD_GLOBAL             30 (__instrument__)
#            1222 CALL_FUNCTION            0
#            1224 POP_TOP
#            1226 COMPARE_OP               3 (!=)
#            1228 LOAD_GLOBAL             30 (__instrument__)
#            1230 CALL_FUNCTION            0
#            1232 POP_TOP
#            1234 EXTENDED_ARG             7
#            1236 POP_JUMP_IF_FALSE     1794
#            1238 LOAD_NAME               15 (row)
#            1240 LOAD_GLOBAL             30 (__instrument__)
#            1242 CALL_FUNCTION            0
#            1244 POP_TOP
#            1246 LOAD_NAME               17 (forward)
#            1248 LOAD_GLOBAL             30 (__instrument__)
#            1250 CALL_FUNCTION            0
#            1252 POP_TOP
#            1254 BINARY_ADD
#            1256 LOAD_GLOBAL             30 (__instrument__)
#            1258 CALL_FUNCTION            0
#            1260 POP_TOP
#            1262 LOAD_NAME                2 (board_size)
#            1264 LOAD_GLOBAL             30 (__instrument__)
#            1266 CALL_FUNCTION            0
#            1268 POP_TOP
#            1270 COMPARE_OP               3 (!=)
#            1272 LOAD_GLOBAL             30 (__instrument__)
#            1274 CALL_FUNCTION            0
#            1276 POP_TOP
#            1278 EXTENDED_ARG             7
#            1280 POP_JUMP_IF_FALSE     1794
#            1282 LOAD_NAME               18 (check_space_wrapper)
#            1284 LOAD_GLOBAL             30 (__instrument__)
#            1286 CALL_FUNCTION            0
#            1288 POP_TOP
#            1290 LOAD_NAME               15 (row)
#            1292 LOAD_GLOBAL             30 (__instrument__)
#            1294 CALL_FUNCTION            0
#            1296 POP_TOP
#            1298 LOAD_NAME               17 (forward)
#            1300 LOAD_GLOBAL             30 (__instrument__)
#            1302 CALL_FUNCTION            0
#            1304 POP_TOP
#            1306 BINARY_ADD
#            1308 LOAD_GLOBAL             30 (__instrument__)
#            1310 CALL_FUNCTION            0
#            1312 POP_TOP
#            1314 LOAD_NAME               16 (col)
#            1316 LOAD_GLOBAL             30 (__instrument__)
#            1318 CALL_FUNCTION            0
#            1320 POP_TOP
#            1322 LOAD_NAME                2 (board_size)
#            1324 LOAD_GLOBAL             30 (__instrument__)
#            1326 CALL_FUNCTION            0
#            1328 POP_TOP
#            1330 CALL_FUNCTION            3
#            1332 EXTENDED_ARG             7
#            1334 POP_JUMP_IF_TRUE      1794
#
#  33        1336 LOAD_NAME               20 (move_forward)
#            1338 LOAD_GLOBAL             30 (__instrument__)
#            1340 CALL_FUNCTION            0
#            1342 POP_TOP
#            1344 CALL_FUNCTION            0
#            1346 POP_TOP
#            1348 LOAD_GLOBAL             30 (__instrument__)
#            1350 CALL_FUNCTION            0
#            1352 POP_TOP
#
#  34        1354 LOAD_NAME                0 (dlog)
#            1356 LOAD_GLOBAL             30 (__instrument__)
#            1358 CALL_FUNCTION            0
#            1360 POP_TOP
#            1362 LOAD_CONST              16 ('Moved forward!')
#            1364 LOAD_GLOBAL             30 (__instrument__)
#            1366 CALL_FUNCTION            0
#            1368 POP_TOP
#            1370 CALL_FUNCTION            1
#            1372 POP_TOP
#            1374 LOAD_GLOBAL             30 (__instrument__)
#            1376 CALL_FUNCTION            0
#            1378 POP_TOP
#         >> 1380 EXTENDED_ARG             1
#            1382 JUMP_FORWARD           410 (to 1794)
#
#  40     >> 1384 LOAD_NAME                4 (team)
#            1386 LOAD_GLOBAL             30 (__instrument__)
#            1388 CALL_FUNCTION            0
#            1390 POP_TOP
#            1392 LOAD_NAME                5 (_getattr_)
#            1394 LOAD_GLOBAL             30 (__instrument__)
#            1396 CALL_FUNCTION            0
#            1398 POP_TOP
#            1400 LOAD_NAME                6 (Team)
#            1402 LOAD_GLOBAL             30 (__instrument__)
#            1404 CALL_FUNCTION            0
#            1406 POP_TOP
#            1408 LOAD_CONST               2 ('WHITE')
#            1410 LOAD_GLOBAL             30 (__instrument__)
#            1412 CALL_FUNCTION            0
#            1414 POP_TOP
#            1416 CALL_FUNCTION            2
#            1418 COMPARE_OP               2 (==)
#            1420 LOAD_GLOBAL             30 (__instrument__)
#            1422 CALL_FUNCTION            0
#            1424 POP_TOP
#            1426 EXTENDED_ARG             5
#            1428 POP_JUMP_IF_FALSE     1448
#
#  41        1430 LOAD_CONST              17 (0)
#            1432 LOAD_GLOBAL             30 (__instrument__)
#            1434 CALL_FUNCTION            0
#            1436 POP_TOP
#            1438 STORE_NAME              21 (index)
#            1440 LOAD_GLOBAL             30 (__instrument__)
#            1442 CALL_FUNCTION            0
#            1444 POP_TOP
#            1446 JUMP_FORWARD            32 (to 1480)
#
#  43     >> 1448 LOAD_NAME                2 (board_size)
#            1450 LOAD_GLOBAL             30 (__instrument__)
#            1452 CALL_FUNCTION            0
#            1454 POP_TOP
#            1456 LOAD_CONST              11 (1)
#            1458 LOAD_GLOBAL             30 (__instrument__)
#            1460 CALL_FUNCTION            0
#            1462 POP_TOP
#            1464 BINARY_SUBTRACT
#            1466 LOAD_GLOBAL             30 (__instrument__)
#            1468 CALL_FUNCTION            0
#            1470 POP_TOP
#            1472 STORE_NAME              21 (index)
#            1474 LOAD_GLOBAL             30 (__instrument__)
#            1476 CALL_FUNCTION            0
#            1478 POP_TOP
#         >> 1480 EXTENDED_ARG             1
#
#  45        1482 SETUP_LOOP             310 (to 1794)
#            1484 LOAD_NAME               14 (_getiter_)
#            1486 LOAD_GLOBAL             30 (__instrument__)
#            1488 CALL_FUNCTION            0
#            1490 POP_TOP
#            1492 LOAD_NAME               22 (range)
#            1494 LOAD_GLOBAL             30 (__instrument__)
#            1496 CALL_FUNCTION            0
#            1498 POP_TOP
#            1500 LOAD_NAME                2 (board_size)
#            1502 LOAD_GLOBAL             30 (__instrument__)
#            1504 CALL_FUNCTION            0
#            1506 POP_TOP
#            1508 CALL_FUNCTION            1
#            1510 CALL_FUNCTION            1
#            1512 GET_ITER
#            1514 LOAD_GLOBAL             30 (__instrument__)
#            1516 CALL_FUNCTION            0
#            1518 POP_TOP
#         >> 1520 EXTENDED_ARG             1
#            1522 FOR_ITER               262 (to 1786)
#            1524 STORE_NAME              23 (_)
#            1526 LOAD_GLOBAL             30 (__instrument__)
#            1528 CALL_FUNCTION            0
#            1530 POP_TOP
#
#  46        1532 LOAD_NAME                5 (_getattr_)
#            1534 LOAD_GLOBAL             30 (__instrument__)
#            1536 CALL_FUNCTION            0
#            1538 POP_TOP
#            1540 LOAD_NAME               24 (random)
#            1542 LOAD_GLOBAL             30 (__instrument__)
#            1544 CALL_FUNCTION            0
#            1546 POP_TOP
#            1548 LOAD_CONST              18 ('randint')
#            1550 LOAD_GLOBAL             30 (__instrument__)
#            1552 CALL_FUNCTION            0
#            1554 POP_TOP
#            1556 CALL_FUNCTION            2
#            1558 LOAD_CONST              17 (0)
#            1560 LOAD_GLOBAL             30 (__instrument__)
#            1562 CALL_FUNCTION            0
#            1564 POP_TOP
#            1566 LOAD_NAME                2 (board_size)
#            1568 LOAD_GLOBAL             30 (__instrument__)
#            1570 CALL_FUNCTION            0
#            1572 POP_TOP
#            1574 LOAD_CONST              11 (1)
#            1576 LOAD_GLOBAL             30 (__instrument__)
#            1578 CALL_FUNCTION            0
#            1580 POP_TOP
#            1582 BINARY_SUBTRACT
#            1584 LOAD_GLOBAL             30 (__instrument__)
#            1586 CALL_FUNCTION            0
#            1588 POP_TOP
#            1590 CALL_FUNCTION            2
#            1592 STORE_NAME              25 (i)
#            1594 LOAD_GLOBAL             30 (__instrument__)
#            1596 CALL_FUNCTION            0
#            1598 POP_TOP
#
#  47        1600 LOAD_NAME               26 (check_space)
#            1602 LOAD_GLOBAL             30 (__instrument__)
#            1604 CALL_FUNCTION            0
#            1606 POP_TOP
#            1608 LOAD_NAME               21 (index)
#            1610 LOAD_GLOBAL             30 (__instrument__)
#            1612 CALL_FUNCTION            0
#            1614 POP_TOP
#            1616 LOAD_NAME               25 (i)
#            1618 LOAD_GLOBAL             30 (__instrument__)
#            1620 CALL_FUNCTION            0
#            1622 POP_TOP
#            1624 CALL_FUNCTION            2
#            1626 EXTENDED_ARG             5
#            1628 POP_JUMP_IF_TRUE      1520
#
#  48        1630 LOAD_NAME               27 (spawn)
#            1632 LOAD_GLOBAL             30 (__instrument__)
#            1634 CALL_FUNCTION            0
#            1636 POP_TOP
#            1638 LOAD_NAME               21 (index)
#            1640 LOAD_GLOBAL             30 (__instrument__)
#            1642 CALL_FUNCTION            0
#            1644 POP_TOP
#            1646 LOAD_NAME               25 (i)
#            1648 LOAD_GLOBAL             30 (__instrument__)
#            1650 CALL_FUNCTION            0
#            1652 POP_TOP
#            1654 CALL_FUNCTION            2
#            1656 POP_TOP
#            1658 LOAD_GLOBAL             30 (__instrument__)
#            1660 CALL_FUNCTION            0
#            1662 POP_TOP
#
#  49        1664 LOAD_NAME                0 (dlog)
#            1666 LOAD_GLOBAL             30 (__instrument__)
#            1668 CALL_FUNCTION            0
#            1670 POP_TOP
#            1672 LOAD_CONST              19 ('Spawned unit at: (')
#            1674 LOAD_GLOBAL             30 (__instrument__)
#            1676 CALL_FUNCTION            0
#            1678 POP_TOP
#            1680 LOAD_NAME                8 (str)
#            1682 LOAD_GLOBAL             30 (__instrument__)
#            1684 CALL_FUNCTION            0
#            1686 POP_TOP
#            1688 LOAD_NAME               21 (index)
#            1690 LOAD_GLOBAL             30 (__instrument__)
#            1692 CALL_FUNCTION            0
#            1694 POP_TOP
#            1696 CALL_FUNCTION            1
#            1698 BINARY_ADD
#            1700 LOAD_GLOBAL             30 (__instrument__)
#            1702 CALL_FUNCTION            0
#            1704 POP_TOP
#            1706 LOAD_CONST              14 (', ')
#            1708 LOAD_GLOBAL             30 (__instrument__)
#            1710 CALL_FUNCTION            0
#            1712 POP_TOP
#            1714 BINARY_ADD
#            1716 LOAD_GLOBAL             30 (__instrument__)
#            1718 CALL_FUNCTION            0
#            1720 POP_TOP
#            1722 LOAD_NAME                8 (str)
#            1724 LOAD_GLOBAL             30 (__instrument__)
#            1726 CALL_FUNCTION            0
#            1728 POP_TOP
#            1730 LOAD_NAME               25 (i)
#            1732 LOAD_GLOBAL             30 (__instrument__)
#            1734 CALL_FUNCTION            0
#            1736 POP_TOP
#            1738 CALL_FUNCTION            1
#            1740 BINARY_ADD
#            1742 LOAD_GLOBAL             30 (__instrument__)
#            1744 CALL_FUNCTION            0
#            1746 POP_TOP
#            1748 LOAD_CONST              15 (')')
#            1750 LOAD_GLOBAL             30 (__instrument__)
#            1752 CALL_FUNCTION            0
#            1754 POP_TOP
#            1756 BINARY_ADD
#            1758 LOAD_GLOBAL             30 (__instrument__)
#            1760 CALL_FUNCTION            0
#            1762 POP_TOP
#            1764 CALL_FUNCTION            1
#            1766 POP_TOP
#            1768 LOAD_GLOBAL             30 (__instrument__)
#            1770 CALL_FUNCTION            0
#            1772 POP_TOP
#
#  50        1774 BREAK_LOOP
#            1776 LOAD_GLOBAL             30 (__instrument__)
#            1778 CALL_FUNCTION            0
#            1780 POP_TOP
#            1782 EXTENDED_ARG             5
#            1784 JUMP_ABSOLUTE         1520
#         >> 1786 POP_BLOCK
#            1788 LOAD_GLOBAL             30 (__instrument__)
#            1790 CALL_FUNCTION            0
#            1792 POP_TOP
#
#  52     >> 1794 LOAD_NAME               28 (get_bytecode)
#            1796 LOAD_GLOBAL             30 (__instrument__)
#            1798 CALL_FUNCTION            0
#            1800 POP_TOP
#            1802 CALL_FUNCTION            0
#            1804 STORE_NAME              29 (bytecode)
#            1806 LOAD_GLOBAL             30 (__instrument__)
#            1808 CALL_FUNCTION            0
#            1810 POP_TOP
#
#  53        1812 LOAD_NAME                0 (dlog)
#            1814 LOAD_GLOBAL             30 (__instrument__)
#            1816 CALL_FUNCTION            0
#            1818 POP_TOP
#            1820 LOAD_CONST              20 ('Done! Bytecode left: ')
#            1822 LOAD_GLOBAL             30 (__instrument__)
#            1824 CALL_FUNCTION            0
#            1826 POP_TOP
#            1828 LOAD_NAME                8 (str)
#            1830 LOAD_GLOBAL             30 (__instrument__)
#            1832 CALL_FUNCTION            0
#            1834 POP_TOP
#            1836 LOAD_NAME               29 (bytecode)
#            1838 LOAD_GLOBAL             30 (__instrument__)
#            1840 CALL_FUNCTION            0
#            1842 POP_TOP
#            1844 CALL_FUNCTION            1
#            1846 BINARY_ADD
#            1848 LOAD_GLOBAL             30 (__instrument__)
#            1850 CALL_FUNCTION            0
#            1852 POP_TOP
#            1854 CALL_FUNCTION            1
#            1856 POP_TOP
#            1858 LOAD_GLOBAL             30 (__instrument__)
#            1860 CALL_FUNCTION            0
#            1862 POP_TOP
#            1864 LOAD_CONST              21 (None)
#            1866 LOAD_GLOBAL             30 (__instrument__)
#            1868 CALL_FUNCTION            0
#            1870 POP_TOP
#            1872 RETURN_VALUE

# %%
dis.dis(examplefuncs)
# Out:
#   2           0 LOAD_NAME                0 (dlog)
#               2 LOAD_CONST               0 ('Starting Turn!')
#               4 CALL_FUNCTION            1
#               6 POP_TOP
#
#   3           8 LOAD_NAME                1 (get_board_size)
#              10 CALL_FUNCTION            0
#              12 STORE_NAME               2 (board_size)
#
#   5          14 LOAD_NAME                3 (get_team)
#              16 CALL_FUNCTION            0
#              18 STORE_NAME               4 (team)
#
#   6          20 LOAD_NAME                4 (team)
#              22 LOAD_NAME                5 (Team)
#              24 LOAD_ATTR                6 (BLACK)
#              26 COMPARE_OP               2 (==)
#              28 POP_JUMP_IF_FALSE       36
#              30 LOAD_NAME                5 (Team)
#              32 LOAD_ATTR                7 (WHITE)
#              34 JUMP_FORWARD             4 (to 40)
#         >>   36 LOAD_NAME                4 (team)
#              38 LOAD_ATTR                6 (BLACK)
#         >>   40 STORE_NAME               8 (opp_team)
#
#   7          42 LOAD_NAME                0 (dlog)
#              44 LOAD_CONST               1 ('Team: ')
#              46 LOAD_NAME                9 (str)
#              48 LOAD_NAME                4 (team)
#              50 CALL_FUNCTION            1
#              52 BINARY_ADD
#              54 CALL_FUNCTION            1
#              56 POP_TOP
#
#   9          58 LOAD_NAME               10 (get_type)
#              60 CALL_FUNCTION            0
#              62 STORE_NAME              11 (robottype)
#
#  10          64 LOAD_NAME                0 (dlog)
#              66 LOAD_CONST               2 ('Type: ')
#              68 LOAD_NAME                9 (str)
#              70 LOAD_NAME               11 (robottype)
#              72 CALL_FUNCTION            1
#              74 BINARY_ADD
#              76 CALL_FUNCTION            1
#              78 POP_TOP
#
#  12          80 LOAD_NAME               11 (robottype)
#              82 LOAD_NAME               12 (RobotType)
#              84 LOAD_ATTR               13 (PAWN)
#              86 COMPARE_OP               2 (==)
#              88 EXTENDED_ARG             1
#              90 POP_JUMP_IF_FALSE      382
#
#  13          92 LOAD_NAME               14 (get_location)
#              94 CALL_FUNCTION            0
#              96 UNPACK_SEQUENCE          2
#              98 STORE_NAME              15 (row)
#             100 STORE_NAME              16 (col)
#
#  14         102 LOAD_NAME                0 (dlog)
#             104 LOAD_CONST               3 ('My location is: ')
#             106 LOAD_NAME                9 (str)
#             108 LOAD_NAME               15 (row)
#             110 CALL_FUNCTION            1
#             112 BINARY_ADD
#             114 LOAD_CONST               4 (' ')
#             116 BINARY_ADD
#             118 LOAD_NAME                9 (str)
#             120 LOAD_NAME               16 (col)
#             122 CALL_FUNCTION            1
#             124 BINARY_ADD
#             126 CALL_FUNCTION            1
#             128 POP_TOP
#
#  16         130 LOAD_NAME                4 (team)
#             132 LOAD_NAME                5 (Team)
#             134 LOAD_ATTR                7 (WHITE)
#             136 COMPARE_OP               2 (==)
#             138 POP_JUMP_IF_FALSE      146
#
#  17         140 LOAD_CONST               5 (1)
#             142 STORE_NAME              17 (forward)
#             144 JUMP_FORWARD             4 (to 150)
#
#  19     >>  146 LOAD_CONST               6 (-1)
#             148 STORE_NAME              17 (forward)
#
#  22     >>  150 LOAD_NAME               18 (check_space_wrapper)
#             152 LOAD_NAME               15 (row)
#             154 LOAD_NAME               17 (forward)
#             156 BINARY_ADD
#             158 LOAD_NAME               16 (col)
#             160 LOAD_CONST               5 (1)
#             162 BINARY_ADD
#             164 LOAD_NAME                2 (board_size)
#             166 CALL_FUNCTION            3
#             168 LOAD_NAME                8 (opp_team)
#             170 COMPARE_OP               2 (==)
#             172 POP_JUMP_IF_FALSE      234
#
#  23         174 LOAD_NAME               19 (capture)
#             176 LOAD_NAME               15 (row)
#             178 LOAD_NAME               17 (forward)
#             180 BINARY_ADD
#             182 LOAD_NAME               16 (col)
#             184 LOAD_CONST               5 (1)
#             186 BINARY_ADD
#             188 CALL_FUNCTION            2
#             190 POP_TOP
#
#  24         192 LOAD_NAME                0 (dlog)
#             194 LOAD_CONST               7 ('Captured at: (')
#             196 LOAD_NAME                9 (str)
#             198 LOAD_NAME               15 (row)
#             200 LOAD_NAME               17 (forward)
#             202 BINARY_ADD
#             204 CALL_FUNCTION            1
#             206 BINARY_ADD
#             208 LOAD_CONST               8 (', ')
#             210 BINARY_ADD
#             212 LOAD_NAME                9 (str)
#             214 LOAD_NAME               16 (col)
#             216 LOAD_CONST               5 (1)
#             218 BINARY_ADD
#             220 CALL_FUNCTION            1
#             222 BINARY_ADD
#             224 LOAD_CONST               9 (')')
#             226 BINARY_ADD
#             228 CALL_FUNCTION            1
#             230 POP_TOP
#             232 JUMP_FORWARD           146 (to 380)
#
#  26     >>  234 LOAD_NAME               18 (check_space_wrapper)
#             236 LOAD_NAME               15 (row)
#             238 LOAD_NAME               17 (forward)
#             240 BINARY_ADD
#             242 LOAD_NAME               16 (col)
#             244 LOAD_CONST               5 (1)
#             246 BINARY_SUBTRACT
#             248 LOAD_NAME                2 (board_size)
#             250 CALL_FUNCTION            3
#             252 LOAD_NAME                8 (opp_team)
#             254 COMPARE_OP               2 (==)
#             256 EXTENDED_ARG             1
#             258 POP_JUMP_IF_FALSE      320
#
#  27         260 LOAD_NAME               19 (capture)
#             262 LOAD_NAME               15 (row)
#             264 LOAD_NAME               17 (forward)
#             266 BINARY_ADD
#             268 LOAD_NAME               16 (col)
#             270 LOAD_CONST               5 (1)
#             272 BINARY_SUBTRACT
#             274 CALL_FUNCTION            2
#             276 POP_TOP
#
#  28         278 LOAD_NAME                0 (dlog)
#             280 LOAD_CONST               7 ('Captured at: (')
#             282 LOAD_NAME                9 (str)
#             284 LOAD_NAME               15 (row)
#             286 LOAD_NAME               17 (forward)
#             288 BINARY_ADD
#             290 CALL_FUNCTION            1
#             292 BINARY_ADD
#             294 LOAD_CONST               8 (', ')
#             296 BINARY_ADD
#             298 LOAD_NAME                9 (str)
#             300 LOAD_NAME               16 (col)
#             302 LOAD_CONST               5 (1)
#             304 BINARY_SUBTRACT
#             306 CALL_FUNCTION            1
#             308 BINARY_ADD
#             310 LOAD_CONST               9 (')')
#             312 BINARY_ADD
#             314 CALL_FUNCTION            1
#             316 POP_TOP
#             318 JUMP_FORWARD            60 (to 380)
#
#  31     >>  320 LOAD_NAME               15 (row)
#             322 LOAD_NAME               17 (forward)
#             324 BINARY_ADD
#             326 LOAD_CONST               6 (-1)
#             328 COMPARE_OP               3 (!=)
#             330 EXTENDED_ARG             1
#             332 POP_JUMP_IF_FALSE      500
#             334 LOAD_NAME               15 (row)
#             336 LOAD_NAME               17 (forward)
#             338 BINARY_ADD
#             340 LOAD_NAME                2 (board_size)
#             342 COMPARE_OP               3 (!=)
#             344 EXTENDED_ARG             1
#             346 POP_JUMP_IF_FALSE      500
#             348 LOAD_NAME               18 (check_space_wrapper)
#             350 LOAD_NAME               15 (row)
#             352 LOAD_NAME               17 (forward)
#             354 BINARY_ADD
#             356 LOAD_NAME               16 (col)
#             358 LOAD_NAME                2 (board_size)
#             360 CALL_FUNCTION            3
#             362 EXTENDED_ARG             1
#             364 POP_JUMP_IF_TRUE       500
#
#  33         366 LOAD_NAME               20 (move_forward)
#             368 CALL_FUNCTION            0
#             370 POP_TOP
#
#  34         372 LOAD_NAME                0 (dlog)
#             374 LOAD_CONST              10 ('Moved forward!')
#             376 CALL_FUNCTION            1
#             378 POP_TOP
#         >>  380 JUMP_FORWARD           118 (to 500)
#
#  40     >>  382 LOAD_NAME                4 (team)
#             384 LOAD_NAME                5 (Team)
#             386 LOAD_ATTR                7 (WHITE)
#             388 COMPARE_OP               2 (==)
#             390 EXTENDED_ARG             1
#             392 POP_JUMP_IF_FALSE      400
#
#  41         394 LOAD_CONST              11 (0)
#             396 STORE_NAME              21 (index)
#             398 JUMP_FORWARD             8 (to 408)
#
#  43     >>  400 LOAD_NAME                2 (board_size)
#             402 LOAD_CONST               5 (1)
#             404 BINARY_SUBTRACT
#             406 STORE_NAME              21 (index)
#
#  45     >>  408 SETUP_LOOP              90 (to 500)
#             410 LOAD_NAME               22 (range)
#             412 LOAD_NAME                2 (board_size)
#             414 CALL_FUNCTION            1
#             416 GET_ITER
#         >>  418 FOR_ITER                78 (to 498)
#             420 STORE_NAME              23 (_)
#
#  46         422 LOAD_NAME               24 (random)
#             424 LOAD_METHOD             25 (randint)
#             426 LOAD_CONST              11 (0)
#             428 LOAD_NAME                2 (board_size)
#             430 LOAD_CONST               5 (1)
#             432 BINARY_SUBTRACT
#             434 CALL_METHOD              2
#             436 STORE_NAME              26 (i)
#
#  47         438 LOAD_NAME               27 (check_space)
#             440 LOAD_NAME               21 (index)
#             442 LOAD_NAME               26 (i)
#             444 CALL_FUNCTION            2
#             446 EXTENDED_ARG             1
#             448 POP_JUMP_IF_TRUE       418
#
#  48         450 LOAD_NAME               28 (spawn)
#             452 LOAD_NAME               21 (index)
#             454 LOAD_NAME               26 (i)
#             456 CALL_FUNCTION            2
#             458 POP_TOP
#
#  49         460 LOAD_NAME                0 (dlog)
#             462 LOAD_CONST              12 ('Spawned unit at: (')
#             464 LOAD_NAME                9 (str)
#             466 LOAD_NAME               21 (index)
#             468 CALL_FUNCTION            1
#             470 BINARY_ADD
#             472 LOAD_CONST               8 (', ')
#             474 BINARY_ADD
#             476 LOAD_NAME                9 (str)
#             478 LOAD_NAME               26 (i)
#             480 CALL_FUNCTION            1
#             482 BINARY_ADD
#             484 LOAD_CONST               9 (')')
#             486 BINARY_ADD
#             488 CALL_FUNCTION            1
#             490 POP_TOP
#
#  50         492 BREAK_LOOP
#             494 EXTENDED_ARG             1
#             496 JUMP_ABSOLUTE          418
#         >>  498 POP_BLOCK
#
#  52     >>  500 LOAD_NAME               29 (get_bytecode)
#             502 CALL_FUNCTION            0
#             504 STORE_NAME              30 (bytecode)
#
#  53         506 LOAD_NAME                0 (dlog)
#             508 LOAD_CONST              13 ('Done! Bytecode left: ')
#             510 LOAD_NAME                9 (str)
#             512 LOAD_NAME               30 (bytecode)
#             514 CALL_FUNCTION            1
#             516 BINARY_ADD
#             518 CALL_FUNCTION            1
#             520 POP_TOP
#             522 LOAD_CONST              14 (None)
#             524 RETURN_VALUE

# %%
a = list(dis.get_instructions(examplefuncs))

# %%
for ix,i in enumerate(a[:]):
    a[ix] = Instruction(i)

# %%
iss = [i for i in a if i.opcode == 143]

# %%
iss
# Out:
# []

# %%
dis.hasjrel
# Out:
# [93, 110, 120, 121, 122, 143, 154]

# %%
a[0].opcode
# Out:
# 101
